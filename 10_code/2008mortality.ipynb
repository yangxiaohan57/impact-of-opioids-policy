# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-67aef045c5e8> in <module>
#       1 import pandas as pd
# ----> 2 from zipfile import zipfile
#
# ImportError: cannot import name 'zipfile' from 'zipfile' (/Users/Jennie/opt/anaconda3/lib/python3.7/zipfile.py)

# %%
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "US_VitalStatistics.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# Underlying Cause of Death, 2009.txt            2019-10-01 21:25:30       398417
# __MACOSX/                                      2019-10-03 13:51:52            0
# __MACOSX/._Underlying Cause of Death, 2009.txt 2019-10-01 21:25:30          176
# Underlying Cause of Death, 2008.txt            2019-10-01 21:25:30       398659
# Underlying Cause of Death, 2003.txt            2019-10-01 21:25:30       371567
# Underlying Cause of Death, 2014.txt            2019-10-01 21:25:30       424598
# Underlying Cause of Death, 2015.txt            2019-10-01 21:25:30       427731
# Underlying Cause of Death, 2005.txt            2019-10-01 21:25:30       382237
# Underlying Cause of Death, 2011.txt            2019-10-01 21:25:30       412607
# Underlying Cause of Death, 2010.txt            2019-10-01 21:25:30       405677
# Underlying Cause of Death, 2004.txt            2019-10-01 21:25:30       376159
# ...

# %%
data = pd.read_csv("./Underlying Cause of Death, 2008.txt", error_bad_lines=False, sep="\t")

# %%
data.head(10)
# Out:
#   Notes              County  County Code    Year  Year Code  \
# 0   NaN  Autauga County, AL       1001.0  2008.0     2008.0
# 1   NaN  Baldwin County, AL       1003.0  2008.0     2008.0
# 2   NaN  Baldwin County, AL       1003.0  2008.0     2008.0
# 3   NaN  Baldwin County, AL       1003.0  2008.0     2008.0
# 4   NaN  Barbour County, AL       1005.0  2008.0     2008.0
# 5   NaN     Bibb County, AL       1007.0  2008.0     2008.0
# 6   NaN   Blount County, AL       1009.0  2008.0     2008.0
# 7   NaN   Blount County, AL       1009.0  2008.0     2008.0
# 8   NaN  Bullock County, AL       1011.0  2008.0     2008.0
# 9   NaN   Butler County, AL       1013.0  2008.0     2008.0
#
#                           Drug/Alcohol Induced Cause  \
# 0          All other non-drug and non-alcohol causes
# 1  Drug poisonings (overdose) Unintentional (X40-...
# 2                   All other alcohol-induced causes
# 3          All other non-drug and non-alcohol causes
# ...

# %%
data['Notes'].value_counts()
# Out:
# ---                                                                                                                                 4
# compiled from data provided by the 57 vital statistics jurisdictions through the Vital Statistics Cooperative Program. Accessed     1
# Dataset: Underlying Cause of Death, 1999-2017                                                                                       1
# Show Suppressed: False                                                                                                              1
# Query Parameters:                                                                                                                   1
# Group By: County; Year; Drug/Alcohol Induced Cause                                                                                  1
# 1999-2017 on CDC WONDER Online Database, released December, 2018. Data are from the Multiple Cause of Death Files, 1999-2017, as    1
# ...

# %%
len(data["County"].unique())
# Out:
# 3105

# %%
data.sample(30)
# Out:
#      Notes                    County  County Code    Year  Year Code  \
# 3169   NaN        Yamhill County, OR      41071.0  2008.0     2008.0
# 3257   NaN     Montgomery County, PA      42091.0  2008.0     2008.0
# 1684   NaN        Calvert County, MD      24009.0  2008.0     2008.0
# 771    NaN         Fulton County, GA      13121.0  2008.0     2008.0
# 3958   NaN       Buchanan County, VA      51027.0  2008.0     2008.0
# 4162   NaN      Snohomish County, WA      53061.0  2008.0     2008.0
# 1677   NaN   Anne Arundel County, MD      24003.0  2008.0     2008.0
# 1024   NaN          Macon County, IL      17115.0  2008.0     2008.0
# 17     NaN           Clay County, AL       1027.0  2008.0     2008.0
# 2391   NaN        Douglas County, NV      32005.0  2008.0     2008.0
# 3386   NaN        Buffalo County, SD      46017.0  2008.0     2008.0
# 3131   NaN      Jefferson County, OR      41031.0  2008.0     2008.0
# 1287   NaN  Pottawattamie County, IA      19155.0  2008.0     2008.0
# ...

# %%
data[data['County'].str.endswith('FL', na=False)]
# Out:
#     Notes                 County  County Code    Year  Year Code  \
# 536   NaN     Alachua County, FL      12001.0  2008.0     2008.0
# 537   NaN     Alachua County, FL      12001.0  2008.0     2008.0
# 538   NaN       Baker County, FL      12003.0  2008.0     2008.0
# 539   NaN         Bay County, FL      12005.0  2008.0     2008.0
# 540   NaN         Bay County, FL      12005.0  2008.0     2008.0
# ..    ...                    ...          ...     ...        ...
# 684   NaN     Volusia County, FL      12127.0  2008.0     2008.0
# 685   NaN     Volusia County, FL      12127.0  2008.0     2008.0
# 686   NaN     Wakulla County, FL      12129.0  2008.0     2008.0
# 687   NaN      Walton County, FL      12131.0  2008.0     2008.0
# 688   NaN  Washington County, FL      12133.0  2008.0     2008.0
#
#                             Drug/Alcohol Induced Cause  \
# 536                   All other alcohol-induced causes
# 537          All other non-drug and non-alcohol causes
# ...

# %%
data[['County1','State']] = data.County.str.split(",",expand=True)

# %%
data
# Out:
#                                                   Notes              County  \
# 0                                                   NaN  Autauga County, AL
# 1                                                   NaN  Baldwin County, AL
# 2                                                   NaN  Baldwin County, AL
# 3                                                   NaN  Baldwin County, AL
# 4                                                   NaN  Barbour County, AL
# ...                                                 ...                 ...
# 4379  Suggested Citation: Centers for Disease Contro...                 NaN
# 4380  1999-2017 on CDC WONDER Online Database, relea...                 NaN
# 4381  compiled from data provided by the 57 vital st...                 NaN
# 4382  at http://wonder.cdc.gov/ucd-icd10.html on Oct...                 NaN
# 4383                                                ---                 NaN
#
#       County Code    Year  Year Code  \
# ...

# %%
data['Notes'].isnull().all()
# Out:
# False

# %%
data
# Out:
#                                                   Notes              County  \
# 0                                                   NaN  Autauga County, AL
# 1                                                   NaN  Baldwin County, AL
# 2                                                   NaN  Baldwin County, AL
# 3                                                   NaN  Baldwin County, AL
# 4                                                   NaN  Barbour County, AL
# ...                                                 ...                 ...
# 4379  Suggested Citation: Centers for Disease Contro...                 NaN
# 4380  1999-2017 on CDC WONDER Online Database, relea...                 NaN
# 4381  compiled from data provided by the 57 vital st...                 NaN
# 4382  at http://wonder.cdc.gov/ucd-icd10.html on Oct...                 NaN
# 4383                                                ---                 NaN
#
#       County Code    Year  Year Code  \
# ...

# %%
data[data['Notes'].notnull()]
# Out:
#                                                   Notes County  County Code  \
# 4369                                                ---    NaN          NaN
# 4370      Dataset: Underlying Cause of Death, 1999-2017    NaN          NaN
# 4371                                  Query Parameters:    NaN          NaN
# 4372  Group By: County; Year; Drug/Alcohol Induced C...    NaN          NaN
# 4373                              Show Totals: Disabled    NaN          NaN
# 4374                         Show Zero Values: Disabled    NaN          NaN
# 4375                             Show Suppressed: False    NaN          NaN
# 4376                                                ---    NaN          NaN
# 4377  Help: See http://wonder.cdc.gov/wonder/help/uc...    NaN          NaN
# 4378                                                ---    NaN          NaN
# 4379  Suggested Citation: Centers for Disease Contro...    NaN          NaN
# ...

# %%
# drop Notes column
